# %%
# !pip install feature_engine

# %%
import pandas as pd
import numpy as np

# %%
'''
EDA : Exploratory Data Analysis - Understanding what is there inside the data

Iteration 01 :
1. Read to the Data and print head
2. Shape of the data
3. Information about the data
4. Finding the duplicate rows, drop the duplicate rows
5. Find the basic statistics of the continuous data columns
6. Rename the columns (optional)
7. Find the missing values (Percentage optional)
8. Finiding basic statistics of categorical columns
9. Basic count analysis on categorical columns

Iteration 02:

1. Univariate Analysis
2. Target column univariate analysis
3. Rest of the categorical columns
4. Numrical columns
'''
# Out:
# '\nEDA : Exploratory Data Analysis - Understanding what is there inside the data\n\nIteration 01 :\n1. Read to the Data and print head\n2. Shape of the data\n3. Information about the data\n4. Finding the duplicate rows, drop the duplicate rows\n5. Find the basic statistics of the continuous data columns\n6. Rename the columns (optional)\n7. Find the missing values (Percentage optional)\n8. Finiding basic statistics of categorical columns\n9. Basic count analysis on categorical columns\n\nIteration 02:\n\n1. Univariate Analysis\n2. Target column univariate analysis\n3. Rest of the categorical columns\n4. Numrical columns\n'

# %%
pb=pd.read_csv("/content/adult_eda.csv")

# %%
#To display first few rows of the dataset
pb.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors           13.0
# 1   50  Self-emp-not-inc   83311  Bachelors           13.0
# 2   38           Private  215646    HS-grad            9.0
# 3   53           Private  234721       11th            7.0
# 4   28           Private  338409  Bachelors           13.0
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
#To display shape of the dataset
pb.shape
# Out:
# (32561, 15)

# %%
pb.education.unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
pb.age.unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87])

# %%
pb.workclass.unique()
# Out:
# array(['State-gov', 'Self-emp-not-inc', 'Private', 'Federal-gov',
#        'Local-gov', '?', 'Self-emp-inc', 'Without-pay', 'Never-worked'],
#       dtype=object)

# %%
pb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   31759 non-null  float64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    27493 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: float64(1), int64(5), object(9)
# memory usage: 3.7+ MB

# %%
#To find duplicate values
pb.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 32556    False
# 32557    False
# 32558    False
# 32559    False
# 32560    False
# Length: 32561, dtype: bool

# %%
pb.duplicated().value_counts()
# Out:
# False    32537
# True        24
# dtype: int64

# %%
pb=pb.drop_duplicates()
pb
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors           13.0
# 1       50  Self-emp-not-inc   83311   Bachelors           13.0
# 2       38           Private  215646     HS-grad            9.0
# 3       53           Private  234721        11th            7.0
# 4       28           Private  338409   Bachelors           13.0
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm           12.0
# 32557   40           Private  154374     HS-grad            9.0
# 32558   58           Private  151910     HS-grad            9.0
# 32559   22           Private  201490     HS-grad            9.0
# 32560   52      Self-emp-inc  287927     HS-grad            9.0
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
pb.duplicated().value_counts()
# Out:
# False    32537
# dtype: int64

# %%
#summary statistics for numerical values
pb.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32537.000000  3.253700e+04   31735.000000  32537.000000  32537.000000
# mean      38.585549  1.897808e+05      10.084008   1078.443741     87.368227
# std       13.637984  1.055565e+05       2.575060   7387.957424    403.101833
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.369930e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
#  Rename the columns ----> replacing - with _
pb.columns = pb.columns.str.replace("-","_")

# %%
pb.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
#find the missing values
pb.isnull().sum()
# Out:
# age                  0
# workclass            0
# fnlwgt               0
# education            0
# education_num      802
# marital_status       0
# occupation           0
# relationship      5064
# race                 0
# sex                  0
# capital_gain         0
# capital_loss         0
# hours_per_week       0
# native_country       0
# salary               0
# dtype: int64

# %%
#percentages
pb.isnull().sum()/len(pb)*100
# Out:
# age                0.000000
# workclass          0.000000
# fnlwgt             0.000000
# education          0.000000
# education_num      2.464886
# marital_status     0.000000
# occupation         0.000000
# relationship      15.563820
# race               0.000000
# sex                0.000000
# capital_gain       0.000000
# capital_loss       0.000000
# hours_per_week     0.000000
# native_country     0.000000
# salary             0.000000
# dtype: float64

# %%
pb.describe(include='object')
# Out:
#        workclass education      marital_status      occupation relationship  \
# count      32537     32537               32537           32537        27473
# unique         9        16                   7              15            5
# top      Private   HS-grad  Married-civ-spouse  Prof-specialty      Husband
# freq       22673     10494               14970            4136        13187
#
#          race    sex native_country salary
# count   32537  32537          32537  32537
# unique      5      2             42      2
# top     White   Male  United-States  <=50K
# freq    27795  21775          29153  24698

# %%
print(pb.columns)
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'capital_loss', 'hours_per_week', 'native_country',
#        'salary'],
#       dtype='object')

# %%
categorical_cols =['workclass',	'marital_status',	'occupation',	'relationship',	'race',	'sex','native_country',	'salary']

for i in categorical_cols:
  print(f'Columns Name : {i}')
  print(pb[i].value_counts())
  print('=============================================')
# Out:
# Columns Name : workclass
# Private             22673
# Self-emp-not-inc     2540
# Local-gov            2093
# ?                    1836
# State-gov            1298
# Self-emp-inc         1116
# Federal-gov           960
# Without-pay            14
# Never-worked            7
# Name: workclass, dtype: int64
# ...
# Columns Name : marital_status
# Married-civ-spouse       14970
# Never-married            10667
# Divorced                  4441
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital_status, dtype: int64
# ...
# Columns Name : occupation
# Prof-specialty       4136
# Craft-repair         4094
# Exec-managerial      4065
# Adm-clerical         3768
# Sales                3650
# Other-service        3291
# Machine-op-inspct    2000
# ?                    1843
# Transport-moving     1597
# Handlers-cleaners    1369
# Farming-fishing       992
# Tech-support          927
# ...

# %%
numerical_columns = pb.select_dtypes(include=['int64', 'float64'])

print("Numerical columns:")
print(numerical_columns.columns)
# Out:
# Numerical columns:
# Index(['age', 'fnlwgt', 'education_num', 'capital_gain', 'capital_loss',
#        'hours_per_week'],
#       dtype='object')

# %%
numerical_columns = pb.select_dtypes(include=['int64'])
print("Numerical columns:")
print(numerical_columns.columns)
# Out:
# Numerical columns:
# Index(['age', 'fnlwgt', 'capital_gain', 'capital_loss', 'hours_per_week'], dtype='object')

# %%
numerical_columns = pb.select_dtypes(include=['float64'])
print("Numerical columns:")
print(numerical_columns.columns)
# Out:
# Numerical columns:
# Index(['education_num'], dtype='object')

# %%
categorical_columns = pb.select_dtypes(include=['object'])
print("Categorical columns:")
print(categorical_columns.columns)
# Out:
# Categorical columns:
# Index(['workclass', 'education', 'marital_status', 'occupation',
#        'relationship', 'race', 'sex', 'native_country', 'salary'],
#       dtype='object')

# %%
(pb.astype(str) == '?').any()
# Out:
# age               False
# workclass          True
# fnlwgt            False
# education         False
# education_num     False
# marital_status    False
# occupation         True
# relationship      False
# race              False
# sex               False
# capital_gain      False
# capital_loss      False
# hours_per_week    False
# native_country     True
# salary            False
# dtype: bool

# %% [markdown]
# ##DATA VISUALIZATION

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(x='education', y='age',data=pb)
plt.title('Distribution')
# Out:
# Text(0.5, 1.0, 'Distribution')

# %% [markdown]
# # *UNIVARIATE ANALYSIS*

# %%
pb['salary'].value_counts()
# Out:
# <=50K    24698
# >50K      7839
# Name: salary, dtype: int64

# %%
percentage = pb['salary'].value_counts()/len(pb)*100
percentage
# Out:
# <=50K    75.907428
# >50K     24.092572
# Name: salary, dtype: float64

# %%
plt.pie(percentage,labels = ['<=50k','>50k'],autopct = '%.2f%%',explode=[0,0.1],
       colors = ['purple','orange'],shadow=True)
plt.title("Pie chart of salary",fontsize=10)
# Out:
# Text(0.5, 1.0, 'Pie chart of salary')

# %%
#Box plot for age
plt.figure(figsize=(10,10))
sns.countplot(data=pb,x='workclass')
plt.title('Count og individuals by workclass')
plt.xlabel('Count')
plt.ylabel('Age')
plt.xticks(rotation=45)
plt.show()

# %%
# age

sns.boxplot(x='age',data=pb)
# Out:
# <Axes: xlabel='age'>

# %%
#Histogram for age
plt.figure(figsize=(8, 6))
sns.histplot(pb['age'], bins=20, kde=True, color='green')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(x='age',data=pb,kde=True,bins=20)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
pb['age'].skew()
# Out:
# 0.5576631514973126

# %%
pb['age'].describe()
# Out:
# count    32537.000000
# mean        38.585549
# std         13.637984
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %%
# check the boxplot and histplot/kdeplot by 'salary' levels
plt.figure(figsize=(10,5))
sns.boxplot(x='salary',data=pb,y='age')
# Out:
# <Axes: xlabel='salary', ylabel='age'>

# %%
# Allowing, visually analyze the distribution of 'age' with respect to different salary levels.

plt.figure(figsize=(10,5))
sns.histplot(x='age',data=pb,kde=True,bins=20,hue='salary')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
plt.figure(figsize=(10,5))
sns.kdeplot(x='age',hue='salary',fill=True,data=pb) #even we can use shade instead of fill, but using fill is good than shade
# Out:
# <Axes: xlabel='age', ylabel='Density'>

# %%
'''
check the statistical values by 'salary' levels
'''
#groupby('salary'): This function call groups the DataFrame df by the unique values present in the 'salary' column.
#Essentially, it creates separate groups of data where each group corresponds to a unique value in the 'salary' column.
#['age']: After grouping by 'salary', this part specifies that we are interested in analyzing the 'age' column within each group.
pb.groupby('salary')['age'].describe()
# Out:
#           count       mean        std   min   25%   50%   75%   max
# salary
# <=50K   24698.0  36.787392  14.017335  17.0  25.0  34.0  46.0  90.0
# >50K     7839.0  44.250925  10.520102  19.0  36.0  44.0  51.0  90.0

# %%
# chcek the boxplot to see the extreme values

plt.figure(figsize=(10,5))
sns.boxplot(x='fnlwgt',data=pb)
# Out:
# <Axes: xlabel='fnlwgt'>

# %%
# check the histplot/kdeplot to see distribution features
plt.figure(figsize=(10,5))
sns.kdeplot(x='fnlwgt',data=pb,fill=True)
# Out:
# <Axes: xlabel='fnlwgt', ylabel='Density'>

# %% [markdown]
# # *BIVARIATE* *ANALYSIS*

# %%
# age vs salary
sns.boxplot(x='age', y='salary', data=pb)
# Out:
# <Axes: xlabel='age', ylabel='salary'>

# %%
sns.histplot(x='age',data=pb,bins=30,kde=True,hue='salary')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.kdeplot(x='age',data=pb,shade=True,hue='salary')
# Out:
# <ipython-input-52-bcb27eaf9a97>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='age',data=pb,shade=True,hue='salary')
# <Axes: xlabel='age', ylabel='Density'>

# %%
'''
Conclusion : The mean and median age of the higher income group is higher than lower income group. It means that older generation
possesses more wealth than young.

'''
# Out:
# '\nConclusion : The mean and median age of the higher income group is higher than lower income group. It means that older generation\npossesses more wealth than young.\n\n'

# %%
sns.boxplot(x='fnlwgt',data=pb)
# Out:
# <Axes: xlabel='fnlwgt'>

# %%
sns.kdeplot(x='fnlwgt',data=pb,shade=True)
# Out:
# <ipython-input-55-b3fa95ad11a5>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='fnlwgt',data=pb,shade=True)
# <Axes: xlabel='fnlwgt', ylabel='Density'>

# %%
pb['fnlwgt'].describe()
# Out:
# count    3.253700e+04
# mean     1.897808e+05
# std      1.055565e+05
# min      1.228500e+04
# 25%      1.178270e+05
# 50%      1.783560e+05
# 75%      2.369930e+05
# max      1.484705e+06
# Name: fnlwgt, dtype: float64

# %%
sns.boxplot(x='salary',y='fnlwgt',data=pb)
# Out:
# <Axes: xlabel='salary', ylabel='fnlwgt'>

# %%
sns.kdeplot(x='fnlwgt',hue='salary',data=pb,shade=True)
# Out:
# <ipython-input-58-ac4d7bec8d31>:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(x='fnlwgt',hue='salary',data=pb,shade=True)
# <Axes: xlabel='fnlwgt', ylabel='Density'>

# %%
pb.groupby('salary')['fnlwgt'].describe()
# Out:
#           count           mean            std      min       25%       50%  \
# salary
# <=50K   24698.0  190345.926796  106487.413197  12285.0  117606.0  179465.0
# >50K     7839.0  188000.480674  102554.464101  14878.0  119100.0  176063.0
#
#               75%        max
# salary
# <=50K   238968.25  1484705.0
# >50K    230969.00  1226583.0

# %%
'''
There is no significant difference between lower and higher income groups according to fnlwgt feature

'''
# Out:
# '\nThere is no significant difference between lower and higher income groups according to fnlwgt feature\n\n'

# %% [markdown]
# # To See the relationship between each numeric features by target feature (salary) in one plot basically

# %%
sns.pairplot(pb,hue='salary',palette='viridis',corner=True,diag_kind='kde')

# %%
#check the boxlpot of 'captial_gain' to see extreme values
plt.figure(figsize=(10,5))
sns.boxplot(data=pb,y='capital_loss')
# Out:
# <Axes: ylabel='capital_loss'>

# %%
pb.hours_per_week.describe()
# Out:
# count    32537.000000
# mean        40.440329
# std         12.346889
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000
# Name: hours_per_week, dtype: float64

# %%
# check the boxplot and histplot/kdeplot by 'salary' level
plt.figure(figsize=(10,5))
sns.boxplot(x='hours_per_week',data=pb,y='salary')
# Out:
# <Axes: xlabel='hours_per_week', ylabel='salary'>

# %%
plt.figure(figsize=(10,5))
sns.histplot(x='hours_per_week',hue='salary',data=pb,kde=True,fill=True,bins=20)
# Out:
# <Axes: xlabel='hours_per_week', ylabel='Count'>

# %% [markdown]
# # Categorical Analysis

# %%
## Education
pb.education.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
pb.education.value_counts().reset_index()
# Out:
#            index  education
# 0        HS-grad      10494
# 1   Some-college       7282
# 2      Bachelors       5353
# 3        Masters       1722
# 4      Assoc-voc       1382
# 5           11th       1175
# 6     Assoc-acdm       1067
# 7           10th        933
# 8        7th-8th        645
# 9    Prof-school        576
# 10           9th        514
# 11          12th        433
# 12     Doctorate        413
# 13       5th-6th        332
# 14       1st-4th        166
# 15     Preschool         50

# %%
fig,ax = plt.subplots(figsize=(12,6))
sns.countplot(x='education',data=pb,hue='salary')
ax.set_xticklabels(pb.education.unique(),rotation=45)
# Out:
# <ipython-input-105-2074aa303bd7>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(pb.education.unique(),rotation=45)
# [Text(0, 0, 'Bachelors'),
#  Text(1, 0, 'HS-grad'),
#  Text(2, 0, '11th'),
#  Text(3, 0, 'Masters'),
#  Text(4, 0, '9th'),
#  Text(5, 0, 'Some-college'),
#  Text(6, 0, 'Assoc-acdm'),
#  Text(7, 0, 'Assoc-voc'),
#  Text(8, 0, '7th-8th'),
#  Text(9, 0, 'Doctorate'),
#  Text(10, 0, 'Prof-school'),
#  Text(11, 0, '5th-6th'),
#  Text(12, 0, '10th'),
#  Text(13, 0, '1st-4th'),
#  Text(14, 0, 'Preschool'),
#  Text(15, 0, '12th')]

# %% [markdown]
# # **ENCODING**

# %%
# !pip install feature_engine

# %%
from sklearn.model_selection import train_test_split
from feature_engine.encoding import OneHotEncoder
from feature_engine.datasets import load_titanic

# %%
X,y = load_titanic(return_X_y_frame =True,
                   handle_missing=True,
                   predictors_only=True,
                   cabin="letter_only"
                   )

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y, test_size=0.3,random_state=0)

# %%
X_train.head()
# Out:
#       pclass     sex        age  sibsp  parch     fare cabin embarked
# 501        2  female  13.000000      0      1  19.5000     M        S
# 588        2  female   4.000000      1      1  23.0000     M        S
# 402        2  female  30.000000      1      0  13.8583     M        C
# 1193       3    male  29.881135      0      0   7.7250     M        Q
# 686        3  female  22.000000      0      0   7.7250     M        Q

# %%
X_train.shape
# Out:
# (916, 8)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 916 entries, 501 to 684
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pclass    916 non-null    int64
#  1   sex       916 non-null    object
#  2   age       916 non-null    float64
#  3   sibsp     916 non-null    int64
#  4   parch     916 non-null    int64
#  5   fare      916 non-null    float64
#  6   cabin     916 non-null    object
#  7   embarked  916 non-null    object
# dtypes: float64(2), int64(3), object(3)
# memory usage: 64.4+ KB

# %%
X_train.describe()
# Out:
#            pclass         age       sibsp       parch        fare
# count  916.000000  916.000000  916.000000  916.000000  916.000000
# mean     2.292576   30.164518    0.532751    0.371179   32.532050
# std      0.842576   12.531840    1.125957    0.837508   47.416524
# min      1.000000    0.166700    0.000000    0.000000    0.000000
# 25%      1.000000   23.000000    0.000000    0.000000    7.895800
# 50%      3.000000   29.881135    0.000000    0.000000   14.454200
# 75%      3.000000   35.000000    1.000000    0.000000   31.275000
# max      3.000000   74.000000    8.000000    9.000000  512.329200

# %%
encoder=OneHotEncoder(top_categories=None,variables=['cabin','embarked'],)

# %%
encoder.fit(X_train)
# Out:
# OneHotEncoder(variables=['cabin', 'embarked'])

# %%
transformed_data=encoder.transform(X_train)
